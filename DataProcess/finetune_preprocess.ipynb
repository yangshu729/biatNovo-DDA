# %%
import pandas as pd
import numpy as np

def sample_tsv(input_file, output_file, percentage):
    # 读取tab分割的文件
    df = pd.read_csv(input_file, sep='\t')
    
    # 确保 percentage 在 0 到 100 之间
    if percentage < 0 or percentage > 100:
        raise ValueError("Percentage must be between 0 and 100")
    
    # 计算需要采样的行数
    sample_size = int(len(df) * (percentage / 100))
    
    # 随机采样
    df_sample = df.sample(n=sample_size, random_state=42)

    # 定义修饰替换规则
    modifications = {
        "C(Carbamidomethylation)": "C(+57.02)",
        "M(Oxidation)": "M(+15.99)"
    }

    # 定义一个函数来替换字符串中的修饰并去掉逗号
    def replace_modifications(sequence, feature_id):
        if isinstance(sequence, str):  # 检查是否为字符串
            for original, replacement in modifications.items():
                sequence = sequence.replace(original, replacement)
            # 去掉逗号
            sequence = sequence.replace(',', '')
            return sequence
            
        else:
            print(f"Feature ID {feature_id} has a non-string value: {sequence}")
            return None

    
     # 对目标列应用替换函数
    df_sample['predicted_forward_sequence'] = df_sample.apply(
        lambda row: replace_modifications(row['predicted_forward_sequence'], row['feature_id']), axis=1)
    df_sample['predicted_backward_sequence'] = df_sample.apply(
        lambda row: replace_modifications(row['predicted_backward_sequence'], row['feature_id']), axis=1)

    # 统计包含None值的行数
    none_rows = df_sample[(df_sample['predicted_forward_sequence'].isna()) | (df_sample['predicted_backward_sequence'].isna())]
    none_count = none_rows.shape[0]
    print(f"共有 {none_count} 行包含None值")

    # 剔除掉包含None值的行
    df_sample = df_sample.dropna(subset=['predicted_forward_sequence', 'predicted_backward_sequence'])

    # 将处理后的数据保存为新的tab分隔文件
    df_sample.to_csv(output_file, sep='\t', index=False)
    
    print(f"{percentage}% 的数据已保存到 {output_file}")

# 示例调用
input_file = '/root/v2/sb_transformer_independent_multheadapi/train_dataset_unique.csv1725206105.deepnovo_denovo'  # 输入文件的路径
output_file = '/root/v2/sb_transformer_independent_multheadapi_finetune_100/train_dataset_100.deepnovo_denovo'  # 输出文件的路径
percentage = 100  # 选取 10% 的数据

sample_tsv(input_file, output_file, percentage)
# Out:
# Feature ID F43:376699 has a non-string value: nan
# Feature ID F13:114770 has a non-string value: nan
# Feature ID F32:276088 has a non-string value: nan
# Feature ID F36:244790 has a non-string value: nan
# Feature ID F55:467624 has a non-string value: nan
# Feature ID F39:344468 has a non-string value: nan
# Feature ID F58:488163 has a non-string value: nan
# Feature ID F11:99728 has a non-string value: nan
# Feature ID F32:276864 has a non-string value: nan
# Feature ID F11:102761 has a non-string value: nan
# Feature ID F64:520037 has a non-string value: nan
# Feature ID F49:423350 has a non-string value: nan
# Feature ID F24:202008 has a non-string value: nan
# Feature ID F25:212984 has a non-string value: nan
# Feature ID F26:219528 has a non-string value: nan
# Feature ID F37:308974 has a non-string value: nan
# Feature ID F16:148320 has a non-string value: nan
# Feature ID F2:19094 has a non-string value: nan
# Feature ID F9:18462 has a non-string value: nan
# Feature ID F45:325681 has a non-string value: nan
# Feature ID F29:248590 has a non-string value: nan
# Feature ID F17:153299 has a non-string value: nan
# Feature ID F44:316053 has a non-string value: nan
# Feature ID F23:194199 has a non-string value: nan
# Feature ID F63:513768 has a non-string value: nan
# Feature ID F4:39348 has a non-string value: nan
# Feature ID F8:10023 has a non-string value: nan
# Feature ID F43:380585 has a non-string value: nan
# Feature ID F37:308564 has a non-string value: nan
# Feature ID F20:87732 has a non-string value: nan
# Feature ID F5:51286 has a non-string value: nan
# Feature ID F10:66170 has a non-string value: nan
# Feature ID F16:147652 has a non-string value: nan
# Feature ID F21:95373 has a non-string value: nan
# Feature ID F58:486996 has a non-string value: nan
# Feature ID F8:9713 has a non-string value: nan
# Feature ID F24:202349 has a non-string value: nan
# Feature ID F45:322022 has a non-string value: nan
# Feature ID F11:99300 has a non-string value: nan
# Feature ID F58:487774 has a non-string value: nan
# Feature ID F41:362190 has a non-string value: nan
# Feature ID F37:306265 has a non-string value: nan
# Feature ID F23:186030 has a non-string value: nan
# Feature ID F27:228505 has a non-string value: nan
# Feature ID F23:190210 has a non-string value: nan
# Feature ID F50:426439 has a non-string value: nan
# Feature ID F8:15030 has a non-string value: nan
# Feature ID F1:7424 has a non-string value: nan
# Feature ID F17:152405 has a non-string value: nan
# Feature ID F43:378236 has a non-string value: nan
# Feature ID F42:368482 has a non-string value: nan
# Feature ID F29:253336 has a non-string value: nan
# Feature ID F7:60060 has a non-string value: nan
# Feature ID F29:253370 has a non-string value: nan
# Feature ID F32:283834 has a non-string value: nan
# Feature ID F18:159328 has a non-string value: nan
# Feature ID F51:435591 has a non-string value: nan
# Feature ID F24:195964 has a non-string value: nan
# Feature ID F39:340996 has a non-string value: nan
# Feature ID F46:397830 has a non-string value: nan
# Feature ID F56:479839 has a non-string value: nan
# Feature ID F56:479944 has a non-string value: nan
# Feature ID F61:449879 has a non-string value: nan
# Feature ID F25:208418 has a non-string value: nan
# Feature ID F34:298887 has a non-string value: nan
# Feature ID F12:110428 has a non-string value: nan
# Feature ID F52:390616 has a non-string value: nan
# Feature ID F43:378532 has a non-string value: nan
# Feature ID F6:53241 has a non-string value: nan
# Feature ID F34:296195 has a non-string value: nan
# Feature ID F7:62185 has a non-string value: nan
# Feature ID F24:203995 has a non-string value: nan
# Feature ID F36:238049 has a non-string value: nan
# Feature ID F30:263779 has a non-string value: nan
# Feature ID F25:204086 has a non-string value: nan
# Feature ID F4:41296 has a non-string value: nan
# Feature ID F27:234826 has a non-string value: nan
# Feature ID F51:435279 has a non-string value: nan
# Feature ID F23:186898 has a non-string value: nan
# Feature ID F18:156584 has a non-string value: nan
# Feature ID F27:233404 has a non-string value: nan
# Feature ID F46:396197 has a non-string value: nan
# Feature ID F46:399009 has a non-string value: nan
# Feature ID F33:291922 has a non-string value: nan
# Feature ID F52:385196 has a non-string value: nan
# Feature ID F57:484725 has a non-string value: nan
# Feature ID F24:197338 has a non-string value: nan
# Feature ID F20:87991 has a non-string value: nan
# Feature ID F38:337031 has a non-string value: nan
# Feature ID F43:378723 has a non-string value: nan
# Feature ID F27:225701 has a non-string value: nan
# Feature ID F59:499811 has a non-string value: nan
# Feature ID F41:364547 has a non-string value: nan
# Feature ID F23:191116 has a non-string value: nan
# Feature ID F46:395403 has a non-string value: nan
# Feature ID F48:410889 has a non-string value: nan
# Feature ID F34:300220 has a non-string value: nan
# Feature ID F62:506670 has a non-string value: nan
# Feature ID F36:240774 has a non-string value: nan
# Feature ID F15:133525 has a non-string value: nan
# Feature ID F23:186969 has a non-string value: nan
# Feature ID F49:420569 has a non-string value: nan
# Feature ID F27:234589 has a non-string value: nan
# Feature ID F32:275540 has a non-string value: nan
# Feature ID F36:239378 has a non-string value: nan
# Feature ID F17:153597 has a non-string value: nan
# Feature ID F39:345286 has a non-string value: nan
# Feature ID F40:352378 has a non-string value: nan
# Feature ID F49:420260 has a non-string value: nan
# Feature ID F62:506910 has a non-string value: nan
# Feature ID F16:151293 has a non-string value: nan
# Feature ID F16:145146 has a non-string value: nan
# Feature ID F2:25774 has a non-string value: nan
# Feature ID F10:70274 has a non-string value: nan
# Feature ID F36:240333 has a non-string value: nan
# Feature ID F33:286840 has a non-string value: nan
# Feature ID F22:170104 has a non-string value: nan
# Feature ID F26:216342 has a non-string value: nan
# Feature ID F12:104232 has a non-string value: nan
# Feature ID F44:318491 has a non-string value: nan
# Feature ID F8:11695 has a non-string value: nan
# Feature ID F43:383316 has a non-string value: nan
# Feature ID F58:488957 has a non-string value: nan
# Feature ID F11:100945 has a non-string value: nan
# Feature ID F20:84679 has a non-string value: nan
# Feature ID F36:240563 has a non-string value: nan
# Feature ID F49:421143 has a non-string value: nan
# Feature ID F59:495325 has a non-string value: nan
# Feature ID F8:10867 has a non-string value: nan
# Feature ID F26:218901 has a non-string value: nan
# Feature ID F11:100924 has a non-string value: nan
# Feature ID F57:482777 has a non-string value: nan
# Feature ID F25:213129 has a non-string value: nan
# Feature ID F56:477975 has a non-string value: nan
# Feature ID F36:239035 has a non-string value: nan
# Feature ID F3:29200 has a non-string value: nan
# Feature ID F31:267472 has a non-string value: nan
# 共有 137 行包含None值
# 100% 的数据已保存到 /root/v2/sb_transformer_independent_multheadapi_finetune_100/train_dataset_100.deepnovo_denovo

# %%
import pandas as pd
def filter_rows_by_feature_id(b_file, c_file, d_file):
    # 读取b文件和c文件
    b_df = pd.read_csv(b_file, sep='\t')
    c_df = pd.read_csv(c_file, sep=',')
    headers = c_df.columns.tolist()
    print(f"文件 {c_file} 的表头: {headers}")
    # 从b文件中提取feature_id
    feature_ids = b_df['feature_id'].unique()
    print(c_df['spec_group_id'])
    # 在c文件中筛选出具有相同feature_id的行
    filtered_df = c_df[c_df['spec_group_id'].isin(feature_ids)]

    # 将筛选结果保存到d文件
    filtered_df.to_csv(d_file, sep=',', index=False)

    print(f"已保存包含相同feature_id的行到 {d_file}")

# 示例调用
b_file = '/root/v2/sb_transformer_independent_multheadapi_finetune_100/train_dataset_100.deepnovo_denovo'  # b文件的路径
c_file = '/root/biatnovo/train-data/ftp.peptideatlas.org/biatNovo/train_dataset_unique.csv'  # c文件的路径
d_file = '/root/v2/sb_transformer_independent_multheadapi_finetune_100/train_dataset_100.csv'  # 输出d文件的路径

filter_rows_by_feature_id(b_file, c_file, d_file)
# Out:
# 文件 /root/biatnovo/train-data/ftp.peptideatlas.org/biatNovo/train_dataset_unique.csv 的表头: ['spec_group_id', 'm/z', 'z', 'rt_mean', 'seq', 'scans', 'profile', 'feature area']
# 0             F1:1
# 1             F1:2
# 2             F1:3
# 3             F1:4
# 4             F1:5
#             ...
# 474522    F9:18694
# 474523    F9:18695
# 474524    F9:18696
# 474525    F9:18697
# 474526    F9:18698
# Name: spec_group_id, Length: 474527, dtype: object
# 已保存包含相同feature_id的行到 /root/v2/sb_transformer_independent_multheadapi_finetune_100/train_dataset_100.csv

# %%
import csv
import pandas as pd

def get_feature_ids_with_eos(a_file):
    feature_ids_with_eos = []
    
    # 读取a.csv
    with open(a_file, 'r') as file:
        reader = csv.DictReader(file, delimiter='\t')
        for row in reader:
            # 检查predicted_forward_sequence和predicted_backward_sequence是否包含_EOS
            if '_EOS' in row['predicted_forward_sequence'] or '_EOS' in row['predicted_backward_sequence']:
                # 如果包含_EOS，则将对应的feature_id加入列表
                feature_ids_with_eos.append(row['feature_id'])
    
    return feature_ids_with_eos

def remove_rows_from_b(b_file, feature_ids_with_eos, output_file):
    # 读取b.csv为DataFrame
    b_data = pd.read_csv(b_file)
    print(feature_ids_with_eos)
    # 删除spec_group_id在feature_ids_with_eos中的行
    filtered_b_data = b_data[~b_data['spec_group_id'].isin(feature_ids_with_eos)]
    
    # 保存修改后的b.csv
    filtered_b_data.to_csv(output_file, index=False)


# b_file = '/root/v2/sb_transformer_independent_multheadapi_finetune_100/train_dataset_100.deepnovo_denovo'  # b文件的路径
# c_file = '/root/biatnovo/train-data/ftp.peptideatlas.org/biatNovo/train_dataset_unique.csv'  # c文件的路径
# d_file = '/root/v2/sb_transformer_independent_multheadapi_finetune_100/train_dataset_100.csv'  # 输出d文件的路径
# 文件路径
a_file = '/root/v2/sb_transformer_independent_multheadapi_finetune_100/train_dataset_100.deepnovo_denovo'
b_file = '/root/v2/sb_transformer_independent_multheadapi_finetune_100/train_dataset_100.csv'
output_file = '/root/v2/sb_transformer_independent_multheadapi_finetune_100/filter_train_dataset_100.csv'

# 获取feature_id列表
feature_ids_with_eos = get_feature_ids_with_eos(a_file)

# 删除b.csv中spec_group_id在feature_ids_with_eos中的行
remove_rows_from_b(b_file, feature_ids_with_eos, output_file)

print(f"Filtered b.csv saved to {output_file}")
# Out:
# ['F14:129477', 'F1:682', 'F2:25717', 'F14:131899', 'F21:91318', 'F60:444008', 'F7:64214', 'F47:404482', 'F34:301771', 'F23:192994', 'F25:212959', 'F51:435151', 'F41:356296', 'F18:161262', 'F55:473337', 'F55:474509', 'F3:31521', 'F26:224397', 'F11:103115', 'F16:150030', 'F23:194103', 'F47:403057', 'F35:237235', 'F58:493941', 'F24:196355', 'F26:217551', 'F11:98753', 'F35:237425', 'F18:161707', 'F63:511207', 'F27:232411', 'F31:268794', 'F30:256374', 'F61:446722', 'F1:701', 'F23:190568', 'F22:166960', 'F12:109612', 'F21:95219', 'F37:306623', 'F33:285009', 'F37:306060']
# Filtered b.csv saved to /root/v2/sb_transformer_independent_multheadapi_finetune_100/filter_train_dataset_100.csv
